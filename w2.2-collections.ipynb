# %% [markdown]
# # Collections (the complex data types)
#
# - sets
# - tuples
# - lists
# - dictionaries
# - combine collections

# %%
# set
# no duplicates, no indexed (no order), iterable, collection, mutable (can change)

set1 = {"Ben", "Jason", "Darlene", "Jason", "Erin"}
set_declared = set(("Ben", "Jason", "G", "G", "Darlene"))

print(f"set1 = {set1}")
print(f"set_declared = {set_declared}")
# Out:
# set1 = {'Erin', 'Jason', 'Ben', 'Darlene'}
# set_declared = {'Darlene', 'G', 'Ben', 'Jason'}

# %%
# Method to find overlaps

overlaps =  set1.intersection(set_declared)
overlaps
# Out:
# {'Ben', 'Darlene', 'Jason'}

# %%
# Method to find differences between two sets

diff = set1.difference(set_declared)
diff
# Out:
# {'Erin'}

# %%
set1.add("Halle")
set1
# Out:
# {'Ben', 'Darlene', 'Erin', 'Halle', 'Jason'}

# %%
set1.remove("Darlene")
set1
# Out:
# {'Ben', 'Erin', 'Halle', 'Jason'}

# %%
# Tuple
# non-mutable, duplicates, iterable, indexed

tuple1 = (1,2,3,4)
tuple_declared = tuple((3,4,5,6))

print (f"tuple1 = {tuple1}")
print (f"tuple_declared = {tuple_declared}")
# Out:
# tuple1 = (1, 2, 3, 4)
# tuple_declared = (3, 4, 5, 6)

# %%
tuple1 = (1,2,3,4,5) # overwritng not changing
tuple1
# Out:
# (1, 2, 3, 4, 5)

# %%
tuple1.count(2) # counts occurences of a value
# Out:
# 1

# %%
tuple1.index(1) # return index of value
# Out:
# 0

# %%
print(f"tuple1 = {tuple1}")
tuple1[0] # return value at index 0
# Out:
# tuple1 = (1, 2, 3, 4, 5)
# 1

# %%
# list
# mutable, duplicates, indexed, iterable

list1 = ["G", "G", "Paola", "Emil"]
list_declared = list(("G", "G", "Paola", "Emil"))

print(f"list1 = {list1}")
print(f"list_declared = {list_declared}")
# Out:
# list1 = ['G', 'G', 'Paola', 'Emil']
# list_declared = ['G', 'G', 'Paola', 'Emil']

# %%
# index notation [:]

print(f"list1 = {list1}")
print(f"first index = {list1[0]}")
print (f"last item in list1 = {list1[-1]}")
print(f"series between 2 & 3 items = {list1[1:3]}") # second item is exclusive
print(f"everything before index 3 = {list1[:3]}")
print(f"everything after the first = {list1[1:]}")
# Out:
# list1 = ['G', 'G', 'Paola', 'Emil']
# first index = G
# last item in list1 = Emil
# series between 2 & 3 items = ['G', 'Paola']
# everything before index 3 = ['G', 'G', 'Paola']
# everything after the first = ['G', 'Paola', 'Emil']

# %%
# list methods

added = list1.append("Clare") # add to list
list2 = list1.append("Nathan")
print(f"appended Clare = {list1}") #append does not return a list
print(f"created list2 = {list2}")

removed = list1.pop() # remove
print(f"Removed {removed}. New list1 is {list1}")

list1[1] = "J" # change index
print(f"Index 1 of list1 changed. New list1 = {list1}")

combined_list1 = [list1, list_declared] # combine lists as lists
print(f"Combined list = {combined_list1}")

combined_lists = [*list1, *list_declared] #combine lsits into one list
print(f"Combined lists into 1: {combined_lists}")

list1.extend(list_declared) # combine lists one list
print(f"list1 after extension = {list1}")
# Out:
# appended Clare = ['G', 'G', 'Paola', 'Emil', 'Clare', 'Nathan']
# created list2 = None
# Removed Nathan. New list1 is ['G', 'G', 'Paola', 'Emil', 'Clare']
# Index 1 of list1 changed. New list1 = ['G', 'J', 'Paola', 'Emil', 'Clare']
# Combined list = [['G', 'J', 'Paola', 'Emil', 'Clare'], ['G', 'G', 'Paola', 'Emil']]
# Combined lists into 1: ['G', 'J', 'Paola', 'Emil', 'Clare', 'G', 'G', 'Paola', 'Emil']
# list1 after extension = ['G', 'J', 'Paola', 'Emil', 'Clare', 'G', 'G', 'Paola', 'Emil']

# %%
# Dictionary
# key:value, indexed by key, not ordered, duplicate values but not keys, mutubale
#{key: value, key1: value}

dict1 = {"name": "Nathan", "age": 39}
dict_decalred = dict(name="Nathan", age=39) #we never do this

print(dict_decalred)
dict1
# Out:
# {'name': 'Nathan', 'age': 39}
# {'name': 'Nathan', 'age': 39}

# %%
dict1["name"] # updateget values
# Out:
# 'Nathan'

# %%
dict1["name"] = "Nate" # change values
dict1
# Out:
# {'name': 'Nate', 'age': 39}

# %%
dict1.keys()
# Out:
# dict_keys(['name', 'age'])

# %%
dict1.values()
# Out:
# dict_values(['Nate', 39])

# %%
students = [
    {"name": "G", "age": 18},
    {"name": "Stacy", "age": 18},
    {"name": "John", "age": 21},
]
students
# Out:
# [{'name': 'G', 'age': 18},
#  {'name': 'Stacy', 'age': 18},
#  {'name': 'John', 'age': 21}]

# %%
students[1] #get name of second student
# Out:
# {'name': 'Stacy', 'age': 18}

# %%
students[2]["name"]
# Out:
# 'John'

# %%
students.pop()
# Out:
# {'name': 'John', 'age': 21}

# %%
students.append({"name": "Nate", "age": 24})
students
# Out:
# [{'name': 'G', 'age': 18},
#  {'name': 'Stacy', 'age': 18},
#  {'name': 'Nate', 'age': 24}]

# %%
students[2]["name"] = "Nathan"
students
# Out:
# [{'name': 'G', 'age': 18},
#  {'name': 'Stacy', 'age': 18},
#  {'name': 'Nathan', 'age': 24}]

# %%
dict1 ["name"] = "Bozo"
dict1
# Out:
# {'name': 'Bozo', 'age': 39}
